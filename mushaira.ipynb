# %%
# collecting all data in a single file to train sentencepiece
import os
import re
import sentencepiece as spm


def get_all_text(parent_folder, filename = '.temp', savefile=False, poets = ['mirza-ghalib'], lang_folders = ['ur'], use_poet_folders=False):
    output_file = open(filename, 'w', encoding='utf-8')
    for poet_folder in os.scandir(parent_folder):
        if (use_poet_folders and poet_folder.name not in poets) or not poet_folder.is_dir() or poet_folder.name.startswith('.'):
            continue
        for lang_folder in os.scandir(poet_folder.path):
            if lang_folder.name not in lang_folders:
                continue
            for file in os.scandir(lang_folder.path):
                with open(file, 'r', encoding='utf-8') as f:
                    try:
                        text = f.read()
                        output_file.write(text + '\n')
                    except:
                        continue
    output_file.close()
    text = open(filename, 'r', encoding='utf-8').read()
    if not savefile:
        os.remove(filename)
    return text

                
all_text = get_all_text('dataset/dataset', 'all_text.txt', savefile=True)
print(all_text)
all_text = re.sub(r'\n', '<n>', all_text)
print(all_text.count('<n>'))
spm.SentencePieceTrainer.Train('--input=all_text.txt --model_prefix=urdu_tokenizer --vocab_size=5000 --model_type=bpe --user_defined_symbols=\n')

# %%
import cupy as np

# check tokenizer
mushaira_tokenizer = spm.SentencePieceProcessor(model_file='urdu_tokenizer.model')
mirza_ghalib = get_all_text('dataset/dataset', poets=['mirza-ghalib'], lang_folders=['ur'], use_poet_folders=True)
# print(mirza_ghalib)
tokens = mushaira_tokenizer.encode(mirza_ghalib[:3000], out_type=int)
print(tokens)
decoded = mushaira_tokenizer.decode(tokens)
print(decoded)

# %%
# code credits: https://gist.github.com/karpathy/d4dee566867f8291f086
class VanillaRNN():
    def __init__(self, vocab_size, hidden_size, seq_length, learning_rate=0.01):
        self.Wxh = np.random.randn(hidden_size, vocab_size) * 0.01
        self.Whh = np.random.randn(hidden_size, hidden_size) * 0.01
        self.Why = np.random.randn(vocab_size, hidden_size) * 0.01
        self.bh = np.zeros((hidden_size, 1))
        self.by = np.zeros((vocab_size, 1))
        self.hidden_state = np.zeros((hidden_size, 1))
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.lr = learning_rate

        # memory variables for Adagrad
        self.mWxh, self.mWhh, self.mWhy = np.zeros_like(self.Wxh), np.zeros_like(self.Whh), np.zeros_like(self.Why)
        self.mbh, self.mby = np.zeros_like(self.bh), np.zeros_like(self.by)

        self.smooth_loss = -np.log(1.0/vocab_size)*seq_length

    def _sample(self, p, temperature=1.0):
        # helper function to sample an index from a probability array
        # sampling helps to diversify outputs
        p = np.log(p) / temperature
        p = np.exp(p) / np.sum(np.exp(p))
        return np.argmax(np.random.multinomial(1, p, 1))
    
    def run(self, inputs, targets, iteration):
        """
        inputs,targets are both list of integers.
        hprev is Hx1 array of initial hidden state
        returns the loss, gradients on model parameters, and last hidden state
        """
        xs, hs, ys, ps = {}, {}, {}, {}
        hs[-1] = np.copy(self.hidden_state)
        loss = 0
        # forward pass
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size,1)) # encode in 1-of-k representation
            xs[t][inputs[t]] = 1
            hs[t] = np.tanh(np.dot(self.Wxh, xs[t]) + np.dot(self.Whh, hs[t-1]) + self.bh) # hidden state
            ys[t] = np.dot(self.Why, hs[t]) + self.by # unnormalized log probabilities for next chars
            ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
            loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
        # backward pass: compute gradients going backwards
        dWxh, dWhh, dWhy = np.zeros_like(self.Wxh), np.zeros_like(self.Whh), np.zeros_like(self.Why)
        dbh, dby = np.zeros_like(self.bh), np.zeros_like(self.by)
        dhnext = np.zeros_like(hs[0])
        for t in reversed(range(len(inputs))):
            dy = np.copy(ps[t])
            dy[targets[t]] -= 1 # backprop into y
            dWhy += np.dot(dy, hs[t].T)
            dby += dy
            dh = np.dot(self.Why.T, dy) + dhnext # backprop into h
            dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
            dbh += dhraw
            dWxh += np.dot(dhraw, xs[t].T)
            dWhh += np.dot(dhraw, hs[t-1].T)
            dhnext = np.dot(self.Whh.T, dhraw)
        
        for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
            np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients

        self.hidden_state = hs[len(inputs)-1]

        self.smooth_loss = self.smooth_loss * 0.999 + loss * 0.001
        
        # perform parameter update with Adagrad
        for param, dparam, mem in zip([self.Wxh, self.Whh, self.Why, self.bh, self.by], 
                                        [dWxh, dWhh, dWhy, dbh, dby], 
                                        [self.mWxh, self.mWhh, self.mWhy, self.mbh, self.mby]):
            mem += dparam * dparam
            param += -self.lr * dparam / np.sqrt(mem + 1e-8) # adagrad update
        return loss

    def sample(self, seed_ix, n):
        """ 
        sample a sequence of integers from the model 
        h is memory state, seed_ix is seed letter for first time step
        """
        x = np.zeros((self.vocab_size, 1))
        x[seed_ix] = 1
        ixes = []
        for t in range(n):
            self.hidden_state = np.tanh(np.dot(self.Wxh, x) + np.dot(self.Whh, self.hidden_state) + self.bh)
            y = np.dot(self.Why, self.hidden_state) + self.by
            p = np.exp(y) / np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p=p.ravel(), size=1)
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        return ixes

# %%
seq_length = 25
model = VanillaRNN(mushaira_tokenizer.get_piece_size(), hidden_size=256, seq_length=seq_length, learning_rate=0.01)

epochs = 0
loss = 0
while True:
    for peom in mirza_ghalib.split('\n\n'):
        i = 0
        tokenized_peom = mushaira_tokenizer.encode(peom, out_type=int)
        while (i + 2) < len(tokenized_peom): # we will use <unk> token to repr end of poem
            inputs = np.zeros((seq_length, 1), dtype=int)
            targets = np.zeros((seq_length, 1), dtype=int)
            for j in range(seq_length):
                inputs[j] = tokenized_peom[i+j] if (i+j) < len(tokenized_peom) else mushaira_tokenizer.unk_id()
                targets[j] = tokenized_peom[i+j+1] if (i+j+1) < len(tokenized_peom) else mushaira_tokenizer.unk_id()
            loss = model.run(inputs, targets, i)
            i += seq_length

    
    print('Epochs: ', epochs)
    print('Loss: ', loss)
    sample_ix = model.sample(tokenized_peom[0], 200)
    print(sample_ix)
    txt = mushaira_tokenizer.decode([int(i) for i in sample_ix])
    print('----\n %s \n----' % (txt, ))
    
    epochs += 1
# Out:
# Epochs:  0
# Loss:  [66.80544562]
# [array([0]), array([0]), array([824]), array([0]), array([0]), array([15]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([1924]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([15]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([54]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([55]), array([1917]), array([989]), array([458]), array([109]), array([517]), array([33]), array([518]), array([665]), array([251]), array([4956]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([84]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([4941]), array([0]), array([117]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#   ⁇  ⁇ گاں ⁇  ⁇  ہے ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  بارے ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ہے ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  کیا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  دل عبث قرار خط اور آخر کہ دیکھتے کہوں ہوتاا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  تھا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  پرزے ⁇  در ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# C:\Users\Burhanuddin\AppData\Local\Temp\ipykernel_756\1752097687.py:24: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   txt = mushaira_tokenizer.decode([int(i) for i in sample_ix])
# Epochs:  1
# Loss:  [67.42019591]
# [array([4165]), array([641]), array([1784]), array([24]), array([3610]), array([29]), array([850]), array([4955]), array([3]), array([3034]), array([107]), array([1675]), array([1510]), array([179]), array([1416]), array([20]), array([2840]), array([322]), array([15]), array([162]), array([15]), array([4955]), array([3]), array([4212]), array([152]), array([850]), array([322]), array([1037]), array([4994]), array([21]), array([54]), array([4955]), array([3]), array([598]), array([71]), array([4983]), array([363]), array([2228]), array([188]), array([719]), array([1027]), array([4962]), array([517]), array([4955]), array([3]), array([4975]), array([467]), array([20]), array([1878]), array([4962]), array([416]), array([310]), array([1717]), array([15]), array([1780]), array([53]), array([4955]), array([3]), array([72]), array([1405]), array([1267]), array([246]), array([58]), array([1018]), array([46]), array([1226]), array([35]), array([4955]), array([3]), array([119]), array([181]), array([80]), array([4957]), array([2096]), array([28]), array([135]), array([545]), array([4921]), array([4955]), array([3]), array([4974]), array([16]), array([1902]), array([2554]), array([418]), array([4796]), array([348]), array([3356]), array([25]), array([53]), array([4955]), array([3]), array([4963]), array([3391]), array([36]), array([1421]), array([2704]), array([158]), array([53]), array([79]), array([21]), array([4955]), array([3]), array([4981]), array([3753]), array([704]), array([1000]), array([266]), array([735]), array([745]), array([1027]), array([21]), array([4955]), array([3]), array([4978]), array([4975]), array([1225]), array([2385]), array([115]), array([930]), array([92]), array([130]), array([3098]), array([4955]), array([3]), array([901]), array([58]), array([707]), array([29]), array([131]), array([249]), array([148]), array([20]), array([4955]), array([3]), array([4965]), array([100]), array([1845]), array([50]), array([1718]), array([2960]), array([294]), array([80]), array([521]), array([4955]), array([3]), array([4979]), array([1329]), array([1249]), array([253]), array([24]), array([15]), array([1074]), array([1356]), array([824]), array([4955]), array([3]), array([262]), array([4955]), array([15]), array([2589]), array([4967]), array([217]), array([366]), array([1276]), array([127]), array([467]), array([478]), array([4955]), array([3]), array([281]), array([225]), array([24]), array([58]), array([21]), array([1819]), array([1079]), array([1405]), array([90]), array([1260]), array([15]), array([4955]), array([3]), array([4958]), array([2290]), array([19]), array([313]), array([1210]), array([44]), array([172]), array([4955]), array([3]), array([4986]), array([1284]), array([28]), array([633]), array([29]), array([87]), array([2443]), array([2921])]
# ----
#  دکھاتا راز یوسف نہ بینی کی سمجھا
# معگر کہیے سلامت کبھی تکلف و رکھوں نگاہ ہے تجھ ہے
# دللو سمجھا نگاہ کفذ میں کیا
# شرھرع لا بستر بر انداز رکھتےے آخر
# پ موج و یاربے اسی آہ شہید ہے پرست نہیں
# نے عدم سیر اپنی وہ عرض ہیں جوہر کے
# اب نظر پری چراغاں سے سررز نبرد
# شیا پن اشعار داغ بالش چشم بیدل کو نہیں
# ن عرصۂ تو محشر مختصر گل نہیںند میں
# ق نظروں ہمارے صبر میرے خوں لہو رکھتے میں
# چپ کوہ تہی بے نالہ ہوں پھر غرق
# حب وہ ساز کی گیا اگر غم و
# تکھ حی ہم نازک شہرت جہاں پر چراغ
# آلۂ مرگ گھر نہ ہے لذت رسوائیگاں
# شک  ہےپرس آج تیرے گویا گر موج بہار
#  لیےقی نہ وہ میں آغوش واں عدم مجھبال ہے
# ہیرے ہو راہ گلہ بھی سم
# ص تلک سے آشنا کی اب بیکسی ناب
# ----
# Epochs:  2
# Loss:  [66.99381685]
# [array([396]), array([4121]), array([35]), array([2018]), array([21]), array([36]), array([770]), array([4955]), array([3]), array([820]), array([131]), array([219]), array([55]), array([294]), array([997]), array([2300]), array([25]), array([53]), array([4955]), array([3]), array([1685]), array([55]), array([1151]), array([707]), array([78]), array([24]), array([954]), array([3342]), array([3844]), array([109]), array([4955]), array([3]), array([1357]), array([4980]), array([28]), array([33]), array([115]), array([2169]), array([20]), array([20]), array([1908]), array([37]), array([4955]), array([3]), array([2868]), array([42]), array([454]), array([4560]), array([2240]), array([15]), array([138]), array([15]), array([0]), array([15]), array([57]), array([224]), array([270]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([55]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([2881]), array([27]), array([238]), array([35]), array([2567]), array([294]), array([50]), array([209]), array([19]), array([4955]), array([3]), array([4982]), array([35]), array([118]), array([2700]), array([2787]), array([651]), array([20]), array([28]), array([1047]), array([574]), array([4955]), array([3]), array([3499]), array([152]), array([33]), array([3392]), array([125]), array([728]), array([1147]), array([4367]), array([619]), array([4955]), array([3]), array([4960]), array([48]), array([55]), array([1813]), array([37]), array([2824]), array([53]), array([346]), array([53]), array([4955]), array([3]), array([4964]), array([4971]), array([4986]), array([9]), array([3605]), array([24]), array([3855]), array([2078]), array([709]), array([15]), array([4955]), array([3]), array([4964]), array([4968]), array([445]), array([3593]), array([29]), array([297]), array([476]), array([48]), array([66]), array([4983]), array([4955]), array([3]), array([4979]), array([4960]), array([1531]), array([50]), array([35]), array([99]), array([78]), array([84]), array([24]), array([948]), array([4955]), array([3]), array([711]), array([4964]), array([2485]), array([644]), array([1234]), array([1645])]
# ----
#  وقت نہانی کےرو میں تویاد
# یہ گیافت دل جہاں جوش راس کو نہیں
# زن دل زنجیر ساز نے نہ گاہ ہمہچوں اور
# جوخ سے کہ بے کھنچ و و تلخاں
# تویر غیر استوار خندہ ہےگی ہے ⁇  ہےور خود رات ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  دل ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇ دیکان من کے نوائے جہاں ہم گے ہو
# ف کےنی عداوت حرام منہ و سے حیرت نکلا
# ہولو کہ عقدۂ ہر دیں ساغر حائل اسدؔ
# رتا دل ضعفاں آرائی نہیںبی نہیں
# ملص ب بٹھا نہنائے کلام شراب ہے
# مب یک آئنے کی وفا سناتاالع
# آر آساں ہم کے ط نے تھا نہ رک
# ہممستگی جنوں گزریقہ
# ----
# Epochs:  3
# Loss:  [67.01356376]
# [array([1580]), array([79]), array([994]), array([109]), array([15]), array([33]), array([340]), array([29]), array([4955]), array([3]), array([4969]), array([1155]), array([1235]), array([31]), array([114]), array([20]), array([46]), array([146]), array([15]), array([4955]), array([3]), array([1555]), array([1560]), array([28]), array([2228]), array([274]), array([403]), array([20]), array([1855]), array([250]), array([48]), array([4955]), array([3]), array([4660]), array([100]), array([177]), array([54]), array([827]), array([1875]), array([1530]), array([500]), array([635]), array([0]), array([0]), array([4955]), array([3]), array([4212]), array([100]), array([704]), array([15]), array([2698]), array([1486]), array([170]), array([900]), array([4955]), array([3]), array([4960]), array([4967]), array([21]), array([957]), array([3538]), array([55]), array([1005]), array([29]), array([368]), array([4955]), array([3]), array([4973]), array([4960]), array([118]), array([3386]), array([999]), array([1096]), array([1531]), array([50]), array([287]), array([0]), array([0]), array([4961]), array([0]), array([4955]), array([3]), array([1657]), array([407]), array([1729]), array([331]), array([91]), array([109]), array([2825]), array([24]), array([864]), array([4955]), array([3]), array([57]), array([16]), array([109]), array([46]), array([1703]), array([91]), array([957]), array([15]), array([4955]), array([3]), array([4955]), array([3]), array([4968]), array([1276]), array([1767]), array([15]), array([905]), array([1539]), array([19]), array([412]), array([4955]), array([3]), array([2018]), array([131]), array([4957]), array([116]), array([11]), array([1109]), array([20]), array([1670]), array([4955]), array([3]), array([4964]), array([4961]), array([115]), array([188]), array([116]), array([44]), array([51]), array([191]), array([188]), array([864]), array([4955]), array([3]), array([4972]), array([4987]), array([171]), array([4963]), array([0]), array([33]), array([2501]), array([266]), array([224]), array([4129]), array([4086]), array([4955]), array([3]), array([4965]), array([335]), array([35]), array([135]), array([146]), array([53]), array([494]), array([236]), array([2336]), array([4955]), array([3]), array([380]), array([923]), array([31]), array([2057]), array([70]), array([248]), array([2025]), array([2419]), array([606]), array([46]), array([29]), array([4955]), array([3]), array([4983]), array([4981]), array([91]), array([3804]), array([91]), array([110]), array([3731]), array([2800]), array([864]), array([4955]), array([3]), array([4268]), array([3751]), array([24]), array([345]), array([78]), array([114]), array([115]), array([35]), array([670]), array([4955]), array([3]), array([4968]), array([21]), array([142]), array([3642])]
# ----
#  صیادند رگ اور ہے کہصل کی
# دعظ جانتاوں اک و ہیں پا ہے
# کس خس سے بستر میری خواب و قلم ہوئیتا
# گیرکھ کیوں کیا تیغ پسند گہر اٹھ امید ⁇  ⁇
# دلکھ ہمارے ہے طوفان ظلمانہ چاہیے
# رس میں سمجھےیانی دل باند کی خاک
# گرنی شگفت ذکر ماہ آساں ہم آیا ⁇  ⁇ ک ⁇
#  طورون ہوائے گو پہ اور آزادی نہ کیے
# وریا اور ہیں سنو پہ سمجھے ہے
#
# ب گویا نیم ہےیل معنی ہوین
# رو گیای ہوا س جز و سکوں
# مک بے بر ہوا بھی کر کسی بر کیے
# جط تکن ⁇  کہ عمل میرے خود پیوند سکندر
# تالم کے سر پا نہیںوش یار روزن
# طر پڑےوں جنبش جا ہوئےنام رشتہ ملے ہیں کی
# عق پہ گرفتاری پہ کچھ رکھنے عیسی کیے
# شاہی نزاکت نہ بار نے اک بے کے نکلے
# ب میںھے طاؤس
# ----
# Epochs:  4
# Loss:  [66.84761621]
# [array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([15]), array([2221]), array([186]), array([2201]), array([135]), array([28]), array([3405]), array([41]), array([4955]), array([3]), array([4981]), array([673]), array([1102]), array([2774]), array([1188]), array([4955]), array([3]), array([4280]), array([1328]), array([109]), array([664]), array([94]), array([947]), array([80]), array([2013]), array([4955]), array([3]), array([4981]), array([205]), array([4992]), array([3878]), array([130]), array([44]), array([4958]), array([4483]), array([4957]), array([115]), array([583]), array([4955]), array([3]), array([4972]), array([787]), array([630]), array([735]), array([757]), array([50]), array([3529]), array([3692]), array([4955]), array([3]), array([4981]), array([7]), array([497]), array([1714]), array([221]), array([50]), array([174]), array([502]), array([4955]), array([3]), array([4975]), array([1187]), array([1807]), array([926]), array([4961]), array([827]), array([478]), array([603]), array([1017]), array([4955]), array([3]), array([2723]), array([57]), array([3817]), array([20]), array([1298]), array([450]), array([19]), array([51]), array([4955]), array([3]), array([1029]), array([524]), array([2604]), array([55]), array([746]), array([1192]), array([257]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([15]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#   ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ہے عجز مرےوشی سر سے وادی کا
# قصت غبار ورق بلبل
#  بشکعل اور حسرت ہییٔ پر ویرانی
# قشمؔ خشت پھر بھیہ خوانیی بے قدر
# جبو خم خوں تاب ہم شش کماں
# قیں لگا دولت مگر ہم جائے غالبؔ
# پ گوش جمع آئنہک تیغ بہار حیا دوں
# پنورقل و کیسا جگر ہو کر
# جہ شمع سف دلافل رہیں آئی ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ہے ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# Epochs:  5
# Loss:  [66.27799092]
# [array([2333]), array([21]), array([41]), array([445]), array([19]), array([569]), array([15]), array([4955]), array([3]), array([136]), array([387]), array([53]), array([3574]), array([1127]), array([33]), array([885]), array([188]), array([4955]), array([3]), array([4961]), array([58]), array([831]), array([29]), array([887]), array([4824]), array([729]), array([84]), array([4955]), array([3]), array([4960]), array([100]), array([188]), array([3804]), array([44]), array([125]), array([1074]), array([605]), array([2177]), array([4955]), array([3]), array([1068]), array([4342]), array([1560]), array([619]), array([4982]), array([92]), array([36]), array([24]), array([4617]), array([4991]), array([4955]), array([3]), array([4964]), array([3043]), array([303]), array([25]), array([891]), array([55]), array([143]), array([50]), array([25]), array([4955]), array([3]), array([4980]), array([4968]), array([4955]), array([3]), array([4964]), array([143]), array([4785]), array([53]), array([502]), array([375]), array([4955]), array([3]), array([790]), array([4955]), array([3]), array([4480]), array([2324]), array([466]), array([1525]), array([41]), array([251]), array([377]), array([633]), array([4955]), array([3]), array([4958]), array([4153]), array([51]), array([3410]), array([969]), array([975]), array([297]), array([2187]), array([53]), array([4955]), array([3]), array([711]), array([101]), array([55]), array([103]), array([502]), array([583]), array([1679]), array([537]), array([251]), array([4955]), array([3]), array([1068]), array([55]), array([266]), array([177]), array([4983]), array([33]), array([4618]), array([2973]), array([84]), array([4955]), array([3]), array([4965]), array([4969]), array([1387]), array([36]), array([324]), array([20]), array([124]), array([524]), array([4969]), array([54]), array([4955]), array([0]), array([1088]), array([1479]), array([2770]), array([28]), array([33]), array([1511]), array([265]), array([35]), array([723]), array([393]), array([1383]), array([4955]), array([3]), array([4212]), array([121]), array([386]), array([1742]), array([236]), array([1574]), array([54]), array([135]), array([4955]), array([3]), array([4964]), array([3517]), array([1045]), array([561]), array([33]), array([710]), array([15]), array([2857]), array([29]), array([4955]), array([3]), array([1068]), array([501]), array([1411]), array([188]), array([15]), array([109]), array([635]), array([1089]), array([4969]), array([4955]), array([3]), array([4956]), array([63]), array([49]), array([4986]), array([33]), array([2760]), array([28]), array([395]), array([498]), array([4955]), array([3]), array([915]), array([4961]), array([4645]), array([564]), array([3207]), array([420]), array([46]), array([900]), array([4955]), array([3]), array([1068])]
# ----
#  خرمن میں کا یک ہوضا ہے
# ہر شوق نہیں لڑک تغافل کہ نفس بر
# ک وہ چپ کی خودی حزیں سحر تھا
# رکھ بر گرفتاری بھی ہر لذت لکھ تقاضا
# کہ کہن خس اسدؔف ہوں تو نہرۂۂ
# مسون پوچھ کو کیجے دل جس ہم کو
# خب
# م جس آبلے نہیں غالبؔ لیکن
# یوں
#  جمعیت انجم بزم ریز کا ہوتا مے آشنا
# ہ اجزائے کر پیتے روش گردش وفا روزگار نہیں
# ہم بہ دل ان غالبؔ قدر بیمار صورت ہوتا
# کہ دل میرے کیوںع کہزۂ پیری تھا
# تد شبنم تو دم و سو شمعد کیا  ⁇ دو برگ ناس سے کہ پنہاں خدا کے رب ہوگا دماغ
# دلنہلفماں یار جہان کیا سر
# منیں گدا دید کہ قاتل ہے انتخاب کی
# کہ روز کئے بر ہے اور امیدگزد
# ایک اسص کہ ظرف سے شام لیا
# بہکلیں رخ روانیعد ہیں چاہیے
# کہ
# ----
# Epochs:  6
# Loss:  [65.37292329]
# [array([0]), array([0]), array([0]), array([0]), array([824]), array([1047]), array([1580]), array([25]), array([835]), array([4915]), array([101]), array([909]), array([4955]), array([3]), array([711]), array([1408]), array([2050]), array([347]), array([254]), array([526]), array([15]), array([33]), array([2921]), array([4955]), array([3]), array([60]), array([3523]), array([97]), array([28]), array([227]), array([4815]), array([3134]), array([49]), array([3155]), array([4955]), array([3]), array([820]), array([790]), array([306]), array([36]), array([145]), array([1875]), array([278]), array([1542]), array([4955]), array([3]), array([220]), array([677]), array([62]), array([1844]), array([727]), array([21]), array([80]), array([717]), array([880]), array([4955]), array([3]), array([298]), array([42]), array([4972]), array([6]), array([93]), array([997]), array([15]), array([251]), array([24]), array([4955]), array([3]), array([953]), array([40]), array([4986]), array([28]), array([68]), array([3212]), array([15]), array([1396]), array([3161]), array([15]), array([4955]), array([3]), array([2277]), array([479]), array([65]), array([104]), array([785]), array([33]), array([4974]), array([29]), array([297]), array([49]), array([4955]), array([3]), array([4979]), array([407]), array([251]), array([129]), array([4980]), array([778]), array([15]), array([2403]), array([3887]), array([4955]), array([3]), array([198]), array([188]), array([1077]), array([1237]), array([4508]), array([84]), array([1831]), array([94]), array([48]), array([92]), array([4955]), array([3]), array([4968]), array([634]), array([29]), array([293]), array([33]), array([3613]), array([835]), array([35]), array([802]), array([41]), array([4955]), array([3]), array([1068]), array([240]), array([58]), array([58]), array([885]), array([246]), array([15]), array([4955]), array([3]), array([2584]), array([250]), array([502]), array([1923]), array([92]), array([192]), array([4978]), array([145]), array([4955]), array([3]), array([1691]), array([4959]), array([2817]), array([204]), array([146]), array([118]), array([759]), array([24]), array([4955]), array([3]), array([3856]), array([614]), array([278]), array([4795]), array([425]), array([15]), array([51]), array([450]), array([1991]), array([4955]), array([3]), array([93]), array([194]), array([235]), array([1983]), array([53]), array([445]), array([678]), array([236]), array([15]), array([4955]), array([3]), array([4956]), array([1644]), array([387]), array([49]), array([28]), array([238]), array([909]), array([1916]), array([177]), array([41]), array([0]), array([4955]), array([3]), array([3036]), array([4967]), array([33]), array([237]), array([2230]), array([33]), array([103]), array([92]), array([836])]
# ----
#   ⁇  ⁇  ⁇  ⁇ گاں حیرت صیاد کو خانہ مہری بہ بنے
# ہم مثل کدہ گی کہیں تا ہے کہ ناب
# نایسا کوئی سے ترے جبین ثواب اس سوزن
# یہیوںرت تو عشق پسند درد کھلے
#  لو صحرارا اع بال میں پر خون تماشا
#  کرےیرج مدا جوش ہے ہوتا نہ
#  چاکئیص سے جو سرشار ہےدی عتاب ہے
# بے اح ز کس کرتا کہش کی وفا اس
# آون ہوتا دیکھخ انتظار ہے منص زعم
# یاں بر منترہ فراہم تھا نالے ہیتا ہوں
# ب اتنا کی محبت کہ تپاک خانہ کے کروں کا
# کہ رنگ وہ وہ نفس اپنی ہے
# جن ہوئی غالبؔ کسو ہوںسمچ عشق
# میرو چلتا رہے پانی مست نہ
# وائے زباں درد ایذا آنکھوں ہے کر جگر زیست
# داائے گئے بہتر نہیں یک آئینہ یار ہے
# اقع شوق اس سے من بنے طرب کیوں کا ⁇
# ہےس کہ شب بوئے کہ ان ہوں مانگ
# ----
# Epochs:  7
# Loss:  [64.35326802]
# [array([113]), array([15]), array([29]), array([21]), array([68]), array([3212]), array([35]), array([1448]), array([4955]), array([3]), array([4959]), array([4969]), array([4956]), array([55]), array([28]), array([3200]), array([21]), array([403]), array([141]), array([713]), array([607]), array([4955]), array([3]), array([4964]), array([223]), array([3262]), array([2649]), array([3568]), array([450]), array([141]), array([1875]), array([21]), array([4955]), array([3]), array([4964]), array([100]), array([806]), array([15]), array([20]), array([8]), array([1619]), array([297]), array([236]), array([41]), array([141]), array([786]), array([4955]), array([3]), array([2869]), array([3033]), array([609]), array([942]), array([146]), array([424]), array([65]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([28]), array([582]), array([28]), array([44]), array([78]), array([2256]), array([36]), array([898]), array([41]), array([4183]), array([4955]), array([3]), array([384]), array([1415]), array([618]), array([1426]), array([747]), array([408]), array([28]), array([800]), array([20]), array([1210]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([24]), array([144]), array([29]), array([3896]), array([446]), array([2085]), array([35]), array([931]), array([4955]), array([3]), array([4980]), array([861]), array([332]), array([2417]), array([667]), array([10]), array([7]), array([762]), array([4955]), array([3]), array([4955]), array([3]), array([4974]), array([3557]), array([25]), array([1106]), array([15]), array([678]), array([633]), array([115]), array([1392]), array([4955]), array([3]), array([4961]), array([98]), array([55]), array([46]), array([12]), array([92]), array([44]), array([58]), array([2128]), array([281]), array([491]), array([4955]), array([3]), array([1068]), array([107]), array([4774]), array([28]), array([2317]), array([159]), array([267]), array([359]), array([4955]), array([3]), array([4975]), array([2730]), array([229]), array([21]), array([4828]), array([91]), array([117]), array([61]), array([29])]
# ----
#  لے ہے کی میں جو سرشار کے خفا
# ودا دل سے بہاری میں خواب اے تع مہر
# م کھوٹ خامہ طوق جگر اے پسند میں
# مکھکی ہے و ا وہم وفا یار کا اے گئیں
# جبغل ساقی روح پا کہتے ز ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  سے بعد سے بھی نے گرمی تو چند کا نمایاں
# سا تصور قسم گریہ تن تر سے کہو و گلہ ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  نہ مجھے کی صدف زخم ایجاد کے ہونا
# خطرہ ہمیں خندۂ آتش تیں کھینچ
#
# ش رمز کو دیوانہ ہے آئینہ آشنا بے ہنوز
# کرے دل ہیں ن ہوں بھی وہ دگر لیے دع
# کہگر کاو سے گنہ رہاباں میرا
# پواب دے میں خفتہ پہ در یہ کی
# ----
# Epochs:  8
# Loss:  [63.28828044]
# [array([15]), array([336]), array([1575]), array([20]), array([2249]), array([64]), array([466]), array([28]), array([4955]), array([3]), array([4634]), array([114]), array([2460]), array([446]), array([21]), array([3432]), array([21]), array([4955]), array([3]), array([4974]), array([636]), array([15]), array([135]), array([1471]), array([301]), array([40]), array([84]), array([4955]), array([3]), array([4968]), array([2500]), array([24]), array([101]), array([1774]), array([2062]), array([4957]), array([502]), array([299]), array([53]), array([4955]), array([3]), array([1496]), array([328]), array([4980]), array([246]), array([1849]), array([127]), array([186]), array([1127]), array([35]), array([4955]), array([3]), array([4961]), array([877]), array([21]), array([20]), array([141]), array([4109]), array([3188]), array([2950]), array([4615]), array([41]), array([4955]), array([3]), array([4974]), array([202]), array([1148]), array([2659]), array([28]), array([3140]), array([619]), array([28]), array([4983]), array([159]), array([4955]), array([3]), array([3499]), array([275]), array([54]), array([2460]), array([3797]), array([3202]), array([21]), array([688]), array([147]), array([4955]), array([3]), array([1555]), array([1293]), array([1189]), array([235]), array([104]), array([406]), array([36]), array([46]), array([120]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([84]), array([0]), array([0]), array([0]), array([651]), array([524]), array([70]), array([53]), array([437]), array([15]), array([144]), array([603]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([4194]), array([0]), array([15]), array([229])]
# ----
#  ہے ساتھ خالی و مرتا ح بزم سے
# دید اک دعائیں زخم میں تقریر میں
# شوق ہے سر دب نازئی تھا
# ب سعی نہ بہ جینے روتےی غالبؔ اپنا نہیں
#  غافل ظخ اپنی دیے گر مرے تغافل کے
# ک لیتے میں و اے معذور کثرت خواںبن کا
# ششت قطرہ غربت سے خسرو اسدؔ سےع رہا
# ہواغ کیا دعائیں اٹھائیے تسخیر میں وحشت دن
# کس طاقت جلوۂ گئے کس گزر تو ہیں رو ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  تھا ⁇  ⁇  ⁇  منہ شمع جا نہیں خبر ہے مجھے حیا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  کھولتے ⁇  ہے دے
# ----
# Epochs:  9
# Loss:  [62.22638192]
# [array([94]), array([127]), array([24]), array([33]), array([478]), array([19]), array([15]), array([2276]), array([41]), array([4955]), array([3]), array([820]), array([531]), array([627]), array([36]), array([1343]), array([4993]), array([84]), array([4955]), array([3]), array([3033]), array([418]), array([1318]), array([2417]), array([1225]), array([2243]), array([251]), array([15]), array([4955]), array([3]), array([1738]), array([4956]), array([4027]), array([4851]), array([43]), array([2852]), array([25]), array([3193]), array([20]), array([4955]), array([3]), array([136]), array([2503]), array([28]), array([249]), array([265]), array([44]), array([245]), array([46]), array([4955]), array([3]), array([3044]), array([370]), array([3300]), array([92]), array([926]), array([116]), array([900]), array([15]), array([4955]), array([3]), array([4975]), array([1262]), array([827]), array([49]), array([101]), array([116]), array([41]), array([2491]), array([61]), array([4955]), array([3]), array([63]), array([59]), array([25]), array([21]), array([22]), array([1971]), array([1149]), array([99]), array([278]), array([4955]), array([3]), array([571]), array([57]), array([424]), array([109]), array([840]), array([92]), array([131]), array([97]), array([33]), array([278]), array([4955]), array([3]), array([4212]), array([4983]), array([1853]), array([2753]), array([2495]), array([1099]), array([36]), array([4961]), array([850]), array([4955]), array([3]), array([2881]), array([319]), array([302]), array([143]), array([524]), array([46]), array([83]), array([1498]), array([4955]), array([3]), array([327]), array([4974]), array([2689]), array([312]), array([997]), array([2442]), array([50]), array([15]), array([4955]), array([3]), array([4958]), array([4958]), array([229]), array([880]), array([91]), array([35]), array([623]), array([1036]), array([2942]), array([207]), array([4955]), array([3]), array([4957]), array([2949]), array([15]), array([33]), array([826]), array([1145]), array([35]), array([1100]), array([3326]), array([1496]), array([177]), array([4955]), array([3]), array([4957]), array([42]), array([567]), array([557]), array([46]), array([130]), array([514]), array([1599]), array([36]), array([35]), array([4955]), array([3]), array([820]), array([202]), array([1039]), array([710]), array([104]), array([317]), array([97]), array([1147]), array([1068]), array([4955]), array([3]), array([4961]), array([98]), array([115]), array([1614]), array([252]), array([61]), array([2567]), array([218]), array([4955]), array([3]), array([915]), array([16]), array([3698]), array([3065]), array([31]), array([997]), array([19]), array([301]), array([4955]), array([3]), array([0]), array([0]), array([4959]), array([49]), array([29]), array([1388])]
# ----
#  ہی گر نہ کہ بہار ہو ہے باندھتے کا
# یہاش خراب تو آبادض تھا
# غل داغ خانۂ خندۂ کوہ شاہد ہوتا ہے
# کشا پنبہ زمردئے پیچھے کو آستاں و
# ہر مشق سے اگر خدا بھی کم ہیں
# صافیش اوج ہوں آئنہ ہوا چاہیے ہے
# پوئے تیغ اس بہ ہوا کا بجز یہ
# یکجھ کو میں آ خشک وصال ط درد
# نمور کہتے اورڑا ہوں گیا کوئی کہ درد
# دلع فرق رزق حکم ہوس توک سمجھا
# دیککھا حسن جس شمع ہیں خو فغاں
# کرش تعمیر تیری جوش بیتاب ہم ہے
# ہہ دے تماشا پہ کے کہا فت بہشت کہاں
# ی حلقہ ہے کہ ابر ہنر کے بکھر مکت غافل کیوں
# ییر ہوتے سخن ہیں پھر ہجربور تو کے
# یہشت شیر قاتل کسگا کوئی ساغرکہ
# کرے بے مار نا یہ نوائے سی
# بہیا گواہ آہووں جوش ہو ناز
#  ⁇  ⁇ و اس کی شعلہ
# ----
# Epochs:  10
# Loss:  [61.14332936]
# [array([583]), array([415]), array([4068]), array([213]), array([144]), array([4955]), array([3]), array([4968]), array([4964]), array([4956]), array([978]), array([1603]), array([28]), array([467]), array([54]), array([25]), array([41]), array([4955]), array([3]), array([4212]), array([703]), array([135]), array([346]), array([224]), array([4118]), array([25]), array([242]), array([196]), array([4955]), array([3]), array([711]), array([873]), array([418]), array([1873]), array([28]), array([423]), array([1392]), array([53]), array([322]), array([4955]), array([3]), array([1173]), array([58]), array([401]), array([2926]), array([4974]), array([1875]), array([35]), array([50]), array([332]), array([4955]), array([3]), array([4956]), array([66]), array([29]), array([945]), array([15]), array([4876]), array([15]), array([1103]), array([4957]), array([4964]), array([4955]), array([3]), array([4978]), array([412]), array([762]), array([53]), array([15]), array([33]), array([526]), array([3480]), array([505]), array([144]), array([4955]), array([3]), array([1929]), array([0]), array([141]), array([4597]), array([368]), array([21]), array([36]), array([251]), array([144]), array([4955]), array([3]), array([4996]), array([359]), array([4965]), array([4971]), array([3121]), array([191]), array([28]), array([1003]), array([457]), array([4955]), array([3]), array([4968]), array([241]), array([15]), array([15]), array([40]), array([44]), array([191]), array([287]), array([154]), array([6]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([904]), array([35]), array([3605]), array([2498]), array([84]), array([747]), array([524]), array([1392]), array([4955]), array([3]), array([904]), array([19]), array([686]), array([4508]), array([2559]), array([299]), array([299]), array([74]), array([140]), array([4955]), array([3]), array([4986]), array([4962]), array([144]), array([2389]), array([44]), array([21]), array([91]), array([171]), array([2926]), array([204]), array([4955]), array([3]), array([4959]), array([4958]), array([609]), array([84]), array([450]), array([333]), array([2228]), array([154]), array([4955]), array([3]), array([820]), array([78]), array([4993]), array([2176]), array([1237]), array([20]), array([4468]), array([640]), array([4390]), array([4955]), array([3]), array([1068]), array([113]), array([181]), array([3467]), array([21]), array([4247]), array([68]), array([332]), array([619]), array([4955]), array([3]), array([4984]), array([16]), array([1265]), array([53]), array([2498]), array([551]), array([3996]), array([954]), array([47])]
# ----
#  قدر عالم جواہر اپنے مجھے
# بما دیکھیے طل سے موج کیا کو کا
# دل زمانے سربی خود نمرود کوائی گئی
# ہم لطف داغ مینا سے دوست ہنوز نہیں نگاہ
# جا وہ نو پئےش پسند کے ہم ہمیں
# اال کی حاصل ہے طراز ہے فریبیم
# چین کھینچ نہیں ہے کہ تا سیکڑوںخن مجھے
#  حریف ⁇  اے چھپانا خاک میں تو ہوتا مجھے
# ڈ میراتل کاف کسی سے کہے جل
# بفر ہے ہےئی بھی کسی آیا سا م ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇ وہ کے بٹھا زدہ تھا تن شمع ہنوز
# وہ ہو اشک فراہم بھاری اپنا اپنا قلی
# صے مجھے روا بھی میں پہ تک پئے رہے
# وہ ساقی تھا جگر وہی بستر سا
# یہ نےض تسلیمرہ و بگڑتا جام صفحۂ
# کہلے نظر کیجئے میں بع جو ہمیں اسدؔ
# حیا ہا نہیں زدہ ہوتی شکوے گاہھا
# ----
# Epochs:  11
# Loss:  [60.08884389]
# [array([1445]), array([95]), array([92]), array([28]), array([297]), array([50]), array([226]), array([900]), array([4955]), array([3]), array([2869]), array([4971]), array([954]), array([775]), array([29]), array([1081]), array([224]), array([682]), array([15]), array([4955]), array([3]), array([419]), array([839]), array([979]), array([2929]), array([1302]), array([55]), array([41]), array([153]), array([322]), array([4955]), array([3]), array([57]), array([3001]), array([15]), array([4194]), array([4885]), array([186]), array([50]), array([53]), array([4955]), array([3]), array([4961]), array([4968]), array([704]), array([3998]), array([377]), array([340]), array([526]), array([1127]), array([4955]), array([3]), array([4978]), array([4963]), array([21]), array([44]), array([1849]), array([2784]), array([3334]), array([50]), array([235]), array([1547]), array([4955]), array([3]), array([935]), array([55]), array([4993]), array([154]), array([252]), array([55]), array([94]), array([15]), array([22]), array([924]), array([4955]), array([3]), array([4979]), array([48]), array([51]), array([91]), array([44]), array([51]), array([1147]), array([4402]), array([2669]), array([4955]), array([3]), array([4963]), array([25]), array([58]), array([3458]), array([15]), array([735]), array([1027]), array([15]), array([15]), array([4955]), array([3]), array([4964]), array([352]), array([3200]), array([542]), array([25]), array([147]), array([25]), array([70]), array([2363]), array([2228]), array([147]), array([4955]), array([3]), array([1594]), array([4985]), array([148]), array([94]), array([1536]), array([2172]), array([949]), array([24]), array([247]), array([109]), array([4955]), array([3]), array([4982]), array([4974]), array([58]), array([651]), array([184]), array([2228]), array([24]), array([501]), array([1168]), array([324]), array([4955]), array([3]), array([4982]), array([81]), array([4135]), array([4957]), array([331]), array([68]), array([2633]), array([15]), array([251]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([1356]), array([4983]), array([786]), array([4959]), array([20]), array([3077]), array([78]), array([784]), array([19]), array([3513]), array([299]), array([4955]), array([3]), array([419]), array([131]), array([121]), array([784]), array([80]), array([1530]), array([73]), array([110]), array([1817]), array([4955]), array([3]), array([1594]), array([43]), array([4974]), array([133]), array([92]), array([1688]), array([19]), array([443]), array([19]), array([144]), array([4955]), array([3]), array([2021]), array([40]), array([54]), array([169]), array([3410]), array([209]), array([614]), array([20]), array([1832]), array([58]), array([4955]), array([3]), array([121])]
# ----
#  بست یا ہوں سے وفا ہم تری چاہیے
# جبل گاہ صبا کی ظالم خود دشمن ہے
# خمچہوری کشش مانگے دل کا جب نگاہ
# ور عریاں ہے کھولتے لاؤں مرے ہم نہیں
# کب ہمارے طلبی مےصل تا تغافل
# چن میں بھی دیے تشنۂ پیے ہم گئے زنداں
# غم دلض سا نا دل ہی ہے آ ہاں
# آتا کر پہ بھی کر ساغر قبلۂ نمود
# ن کو وہ نکالے ہے خوں رکھتے ہے ہے
# م بن بہاری مہ کو دن کو جا وفائی بستر دن
# تمغ غم ہی داری احباب برق نہ دیا اور
# فش وہ منہ مر بستر نہ روز عزیز دم
# فاہ چھوٹای گو جو وضع ہے ہوتا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  رسوائیع گئیںو و تاک نے پاؤں ہوطنت اپنا
# خم گیانہ پاؤں پر گہرری کچھ نمک
# تمئےش کب ہوںختہ ہو ہائے ہو مجھے
# جادئی کیا ایک پیتے گے زباں و نرگس وہ
# نہ
# ----
# Epochs:  12
# Loss:  [59.10758844]
# [array([0]), array([0]), array([0]), array([0]), array([3218]), array([28]), array([44]), array([20]), array([111]), array([4153]), array([46]), array([46]), array([53]), array([4955]), array([3]), array([4964]), array([7]), array([82]), array([1354]), array([446]), array([36]), array([310]), array([21]), array([25]), array([1008]), array([4955]), array([3]), array([27]), array([359]), array([421]), array([421]), array([1317]), array([15]), array([443]), array([50]), array([4955]), array([3]), array([4212]), array([101]), array([94]), array([384]), array([1421]), array([55]), array([15]), array([730]), array([36]), array([4955]), array([3]), array([1068]), array([4962]), array([28]), array([362]), array([4]), array([387]), array([186]), array([20]), array([1488]), array([15]), array([4955]), array([3]), array([4958]), array([524]), array([15]), array([108]), array([332]), array([562]), array([1727]), array([423]), array([265]), array([4955]), array([3]), array([820]), array([2543]), array([68]), array([497]), array([24]), array([36]), array([1718]), array([19]), array([1971]), array([4955]), array([3]), array([1642]), array([80]), array([1885]), array([50]), array([1267]), array([2019]), array([619]), array([43]), array([140]), array([4011]), array([4955]), array([3]), array([711]), array([0]), array([21]), array([1223]), array([70]), array([624]), array([15]), array([144]), array([177]), array([4955]), array([3]), array([4964]), array([16]), array([21]), array([1292]), array([2196]), array([1624]), array([671]), array([4509]), array([185]), array([900]), array([4955]), array([3]), array([915]), array([35]), array([450]), array([1543]), array([608]), array([109]), array([1977]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([42]), array([575]), array([148]), array([21]), array([238]), array([33]), array([391]), array([15]), array([1940]), array([42]), array([4955]), array([3]), array([4964]), array([145]), array([68]), array([514]), array([39]), array([46]), array([134]), array([4112]), array([68]), array([1875]), array([29]), array([4955]), array([3]), array([1691]), array([240]), array([422]), array([25]), array([58]), array([80]), array([876]), array([313]), array([299]), array([19]), array([4955]), array([3]), array([4971]), array([636]), array([4992]), array([3488]), array([49]), array([33]), array([36])]
# ----
#   ⁇  ⁇  ⁇  ⁇  شوخیٔ سے بھی و جان اجزائے ہیں ہیں نہیں
# میںچھ واسطے زخم تو آہ میں کو کہتا
# ان میرا تیرا تیرا بیاں ہے ہائے ہم
# دل بہ ہیسا محشر دل ہے تمام تو
# کہے سے ہن ک شوق مرے و مسک ہے
# ہ شمع ہےتی ہمیں قدم نظارہ دوست خدا
# یہ نواز جو لگا نہ تو نازک ہو خشک
# اس پر منتظر ہم سیرسب اسدؔئےلی مشرب
# ہم ⁇  میں فصل جا دیوار ہے مجھے کیوں
# میا میں دیدۂفرت تازہ پہنچ فریبی تھے چاہیے
# بہ کے جگر گردن بھول اور نشہ ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇ یر کریں غم میں من کہ مان ہے چاہایر
# م عشق جو ہجر ش ہیں دو میکدے جو پسند کی
# میر رنگ جاتا کو وہ پر اللہ راہ اپنا ہو
# لوقؔ کیونکہ اس کہ تو
# ----
# Epochs:  13
# Loss:  [58.23264309]
# [array([671]), array([29]), array([3813]), array([50]), array([3696]), array([1545]), array([4351]), array([41]), array([251]), array([4955]), array([3]), array([48]), array([44]), array([58]), array([2407]), array([109]), array([55]), array([352]), array([454]), array([19]), array([4955]), array([3]), array([4983]), array([815]), array([467]), array([1486]), array([29]), array([1185]), array([84]), array([4958]), array([3194]), array([21]), array([97]), array([4955]), array([3]), array([4971]), array([267]), array([33]), array([484]), array([21]), array([19]), array([294]), array([127]), array([837]), array([460]), array([4955]), array([3]), array([743]), array([3164]), array([443]), array([49]), array([265]), array([15]), array([1049]), array([240]), array([229]), array([4955]), array([3]), array([376]), array([4969]), array([1181]), array([36]), array([363]), array([408]), array([2605]), array([299]), array([251]), array([4955]), array([3]), array([4969]), array([178]), array([1343]), array([103]), array([21]), array([872]), array([1531]), array([103]), array([41]), array([4955]), array([3]), array([4212]), array([4970]), array([33]), array([2295]), array([1047]), array([1628]), array([41]), array([207]), array([15]), array([4955]), array([3]), array([4979]), array([961]), array([4958]), array([101]), array([20]), array([1550]), array([2853]), array([4064]), array([28]), array([4955]), array([3]), array([4956]), array([992]), array([2015]), array([3393]), array([4969]), array([68]), array([460]), array([158]), array([4760]), array([4955]), array([3]), array([4983]), array([7]), array([15]), array([4733]), array([48]), array([33]), array([537]), array([1539]), array([28]), array([4955]), array([3]), array([770]), array([4997]), array([4978]), array([4372]), array([69]), array([135]), array([22]), array([50]), array([303]), array([4955]), array([3]), array([4975]), array([40]), array([56]), array([46]), array([450]), array([2698]), array([345]), array([4398]), array([4955]), array([3]), array([4985]), array([16]), array([4965]), array([4961]), array([3858]), array([253]), array([46]), array([50]), array([466]), array([33]), array([407]), array([15]), array([4955]), array([3]), array([1174]), array([1173]), array([15]), array([68]), array([2482]), array([744]), array([919]), array([54]), array([141]), array([0]), array([0]), array([0]), array([0]), array([41]), array([55]), array([21]), array([97]), array([172]), array([2175]), array([635]), array([21]), array([4955]), array([3]), array([4984]), array([89]), array([67]), array([293]), array([266]), array([109]), array([1559]), array([614]), array([3856]), array([4955]), array([3]), array([935]), array([4956]), array([94]), array([903]), array([254]), array([4957]), array([413])]
# ----
#  پہنچ کیشا ہم گشتہ بنایا اختر کا ہوتا
# تا بھی وہ پاب اور دل بن غیر ہو
# ع شخص موج ظلم کی ڈال تھاہ آشکار میں کوئی
# لباں کہ دام میں ہو جہاں گر دیکھنا خیال
#  سوا فسوں ہائے اس خدا ہے ناصح رنگ دے
# کاد داد تو لا تر غش اپنا ہوتا
# دفا آباد ان میں طلب آساں ان کا
# دلھ کہ بشر حیرت سکتے کا کہاں ہے
# آالیہ بہ و گھبرا چاہتے تقریب سے
# اظر گرفتار غمزہد جو خیال گل نشو
# عیں ہے ساںتا کہ صورت معنی سے
# یادثچ دعوا رہ سر آ ہم پوچھ
# پئیتے ہیں جگر طوفان بار فارغ
# غیاتکیازہ گھر ہیں ہم بزم کہون ہے
# ملجا ہے جو قم شرم حج کیا اے ⁇  ⁇  ⁇  ⁇  کا دل میں کوئی سم ایمان امید میں
# حلاات محبت میرے اور اض زباںوائے
# غما ہیشی کہیںی آش
# ----
# Epochs:  14
# Loss:  [57.42819132]
# ...
# ----
#  خون ہم جس میں سلامت ملاقات کیا آخر
# ہوئی تو کروں نہیں ضعف میں مجھے اچھا آئی ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  خندہ بھی ہا ⁇  ہستی کی ذوق بیداد کا کے
# ہ شکست شیر مست شکر تو مجھ یک ملے طوفاں مکاں
# نگر کو صبو جگہد دسترۂ جانو ہم نے ترا اٹھائیے
# رہلو نے دست پہ بزم تھے ضعف پر
# سنعدے گل جیسے خوار سو رکھتے سکوں ہیں ہے
# ح چند لخت کسی پر شہہ تھے
# غمیں ہو کہد اور احساں عافیت
# طاار نہ بنے اگر کیوں پائے پر
# ر رہیںنا سکتا ہمیں گوش خروش انتخاب ہوگا
# جیش خط سے ہیں تھا مینا کے لیے مجھے
# اکئی لالہ عبرت نہیں ہے سلامت توکاں کی
# اسئذ شوق دیکھا رہا ہے مشہور مرے در نہ ہوا
# جال
# ----
# Epochs:  67
# Loss:  [43.02481718]
# [array([235]), array([25]), array([61]), array([92]), array([1265]), array([33]), array([603]), array([94]), array([177]), array([315]), array([4955]), array([3]), array([93]), array([4905]), array([251]), array([101]), array([50]), array([4955]), array([3]), array([4969]), array([93]), array([1188]), array([4963]), array([438]), array([61]), array([3160]), array([109]), array([1881]), array([21]), array([4955]), array([3]), array([118]), array([4194]), array([21]), array([775]), array([4148]), array([591]), array([3452]), array([41]), array([786]), array([4955]), array([3]), array([4967]), array([4958]), array([4957]), array([3471]), array([1172]), array([58]), array([37]), array([177]), array([3214]), array([7]), array([582]), array([1292]), array([4955]), array([3]), array([4964]), array([4997]), array([377]), array([566]), array([1697]), array([15]), array([2681]), array([94]), array([19]), array([2029]), array([822]), array([53]), array([1670]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#  گئے کو یہ ہوں ہا کہ حیا ہی کیوں جانے
# دا مطلع ہوتا بہ ہم
# ددا بلبلن طرف یہ طالع اور حیراں میں
# نی کھولتے میں صبا یاران جسے فردوس کا گئیں
# سہی اٹھانے اختیار وہاں کیوں سمجھویں بعد دیدۂ
# مث مے جیسے رم ہے ارباب ہی ہو ٹپ چار نہیں سکوں ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# Epochs:  68
# Loss:  [44.08282048]
# [array([148]), array([78]), array([58]), array([24]), array([227]), array([2276]), array([46]), array([502]), array([4955]), array([3]), array([2868]), array([4983]), array([4956]), array([28]), array([789]), array([1817]), array([10]), array([3607]), array([733]), array([4048]), array([4955]), array([3]), array([3497]), array([46]), array([1701]), array([21]), array([1041]), array([135]), array([177]), array([134]), array([4955]), array([3]), array([4964]), array([4985]), array([656]), array([103]), array([51]), array([55]), array([35]), array([148]), array([747]), array([29]), array([4955]), array([3]), array([360]), array([840]), array([20]), array([4050]), array([2795]), array([58]), array([3867]), array([3227]), array([2366]), array([15]), array([4183]), array([136]), array([4955]), array([3]), array([4983]), array([4969]), array([1003]), array([19]), array([803]), array([1147]), array([28]), array([50]), array([684]), array([4727]), array([50]), array([4955]), array([3]), array([4982]), array([4962]), array([672]), array([2417]), array([575]), array([58]), array([4827]), array([251]), array([1027]), array([19]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#  غم نے وہ نہ ترے باندھتے ہیں غالبؔ
# توعا سےستے نمک ت بچھا دیکھی ہلال
# مے ہیں جنت میں لیں سر کیوں دو
# مغ آتی ان کر دل کے غم تن کی
# سوڑا و آتشیں زانو وہ بدر معمور گفتار ہے نمایاںہر
# عد کہے ہو آسماں ساغر سے ہماروں دبی ہم
# فے ہستی خندۂ کریں وہ خروش ہوتا رکھتے ہو ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# Epochs:  69
# Loss:  [44.17502218]
# [array([692]), array([2936]), array([1753]), array([15]), array([104]), array([25]), array([237]), array([3646]), array([15]), array([4955]), array([3]), array([327]), array([4991]), array([181]), array([35]), array([4233]), array([46]), array([237]), array([257]), array([80]), array([1350]), array([4955]), array([3]), array([4968]), array([98]), array([4985]), array([741]), array([127]), array([19]), array([1127]), array([300]), array([345]), array([3703]), array([21]), array([4955]), array([3]), array([4956]), array([30]), array([51]), array([584]), array([1345]), array([3798]), array([866]), array([2323]), array([4955]), array([3]), array([4964]), array([7]), array([127]), array([204]), array([1049]), array([104]), array([254]), array([36]), array([251]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#  نقش بنتی دلی ہے کس کو شب ظہور ہے
# کرۂ نظر کےلاط ہیں شب آئی پر نہاں
# برےغ تس گر ہو تغافل تمہ بار انصاف میں
# اار کر شاید رہتے بیگانگی فرصت ابرو
# میں گر رہے ناصح کس کہیں تو ہوتا ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# Epochs:  70
# Loss:  [44.46587904]
# [array([529]), array([2600]), array([15]), array([33]), array([125]), array([717]), array([55]), array([4956]), array([954]), array([3710]), array([4955]), array([3]), array([1642]), array([4973]), array([158]), array([2057]), array([15]), array([33]), array([310]), array([46]), array([251]), array([21]), array([4955]), array([3]), array([3499]), array([240]), array([1896]), array([4109]), array([1345]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0]), array([0])]
# ----
#  کارچھے ہے کہ ہر خون دلا گاہ بلائے
# اسگ گل جنبش ہے کہ آہ ہیں ہوتا میں
# ہو رنگلیٰ معذور رہتے ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 16
#      14             inputs[j] = tokenized_peom[i+j] if (i+j) < len(tokenized_peom) else mushaira_tokenizer.unk_id()
#      15             targets[j] = tokenized_peom[i+j+1] if (i+j+1) < len(tokenized_peom) else mushaira_tokenizer.unk_id()
# ---> 16         loss = model.run(inputs, targets, i)
#      17         i += seq_length
#      20 print('Epochs: ', epochs)
#
# Cell In[119], line 57, in VanillaRNN.run(self, inputs, targets, iteration)
#      55     dbh += dhraw
#      56     dWxh += np.dot(dhraw, xs[t].T)
# ---> 57     dWhh += np.dot(dhraw, hs[t-1].T)
#      58     dhnext = np.dot(self.Whh.T, dhraw)
#      60 for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#
# File c:\Users\Burhanuddin\miniconda3\Lib\site-packages\cupy\linalg\_product.py:63, in dot(a, b, out)
#      44 """Returns a dot product of two arrays.
#      45
#      46 For arrays with more than one axis, it computes the dot product along the
#    (...)
#      60
#      61 """
#      62 # TODO(okuta): check type
# ---> 63 return a.dot(b, out)
#
# KeyboardInterrupt:

# %%
import cupy as np
np.cuda.Device(0).use()
# Out:
# <CUDA Device 0>
